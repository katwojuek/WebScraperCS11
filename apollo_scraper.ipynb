# %% [markdown]
# # Packages import

# %%
import os
import re
import yaml
import requests
import pandas as pd
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup

# %% [markdown]
# # Apollo scraper

# %%
with open("config.yaml", "r", encoding="UTF-8") as yf:
    config = yaml.safe_load(yf)
username = config['credentials']['user']
password = config['credentials']['password']
credentials = HTTPBasicAuth(username, password)

# %%
group_id = input("Enter group ID: ")
url = f"https://planzajec.uek.krakow.pl/index.php?typ=G&id={group_id}&okres=2"
response = requests.get(url, auth=credentials)
response.encoding = "UTF-8"
print(response.status_code)
# Out:
# 200

# %%
page_dom = BeautifulSoup(response.text, 'html.parser')

# %%
group = page_dom.select_one("div.grupa").get_text(strip=True)
print(group)
# Out:
# ZICSS1-1211

# %%
classes_tag = page_dom.select_one("table")
with open("temp.html", "w", encoding="UTF-8") as hf:
    hf.write(classes_tag.prettify())
classes = pd.read_html("temp.html", encoding="UTF-8")[0]
os.remove("temp.html")

# %%
classes
# Out:
#          Termin          Dzień, godzina  \
# 0    2026-02-23  Pn 11:30 - 13:00 (2g.)
# 1    2026-02-23  Pn 13:15 - 15:45 (3g.)
# 2    2026-02-23  Pn 13:15 - 15:45 (3g.)
# 3    2026-02-23  Pn 18:30 - 20:00 (2g.)
# 4    2026-02-24  Wt 09:45 - 11:15 (2g.)
# ..          ...                     ...
# 305  2026-06-11  Cz 18:30 - 20:00 (2g.)
# 306  2026-06-11  Cz 18:30 - 20:00 (2g.)
# 307  2026-06-17  Śr 10:30 - 13:00 (3g.)
# 308  2026-06-26  Pt 10:30 - 12:15 (2g.)
# 309  2026-09-03  Cz 10:30 - 13:00 (3g.)
#
#                                    Przedmiot        Typ  \
# 0                         Foreign Language I   lektorat
# 1                     Computer Programming 2  ćwiczenia
# 2                                    CS gr 1    CS gr 1
# 3                                        NaN   lektorat
# 4                 Probability and Statistics     wykład
# ..                                       ...        ...
# 305  Operating Systems and Computer Networks  ćwiczenia
# 306                                  CS gr 1    CS gr 1
# 307                     Discrete mathematics    egzamin
# 308  Operating Systems and Computer Networks    egzamin
# 309                     Discrete mathematics    egzamin
#
#                            Nauczyciel                            Sala
# 0                                 NaN    Wybierz swoją grupę językową
# 1                 dr Katarzyna Wójcik  Paw.A 013 lab. Win10, Office21
# 2                             CS gr 1                         CS gr 1
# 3                                 NaN    Wybierz swoją grupę językową
# 4    prof. dr hab. Andrzej Sokołowski                       Paw.F 008
# ..                                ...                             ...
# 305  prof. UEK dr hab. Joanna Wyrobek    Paw.A 07 lab. Win7, Office21
# 306                           CS gr 1                         CS gr 1
# 307           dr Grzegorz Kosiorowski                 Paw.C Nowa Aula
# 308  prof. UEK dr hab. Joanna Wyrobek    Paw.A 07 lab. Win7, Office21
# 309           dr Grzegorz Kosiorowski                       Paw.F 102
#
# [310 rows x 6 columns]

# %%
classes = classes.loc[classes['Typ'].isin(["ćwiczenia", "wykład", "egzamin"])]

# %%
classes[['Day','Start time', 'hyphen', 'End time', "Duration"]] = classes['Dzień, godzina'].str.split(' ',expand=True)

# %%
classes['Duration'] = classes['Duration'].map(lambda x: x.split('(')[1].split('g')[0])

# %%
classes = classes.drop(['Dzień, godzina', 'hyphen'], axis=1)

# %%
classes['Sala'] = classes['Sala'].str.replace(
    r"(lab\.).*",
    r"\1",
    regex=True
)

# %%
if not os.path.exists("schedules"):
    os.mkdir("schedules")

# %%
classes.to_csv(f"schedules/{group}.csv")

# %%
classes
# Out:
#          Termin                                Przedmiot        Typ  \
# 1    2026-02-23                   Computer Programming 2  ćwiczenia
# 4    2026-02-24               Probability and Statistics     wykład
# 6    2026-02-24               Probability and Statistics  ćwiczenia
# 8    2026-02-24                     Discrete mathematics     wykład
# 9    2026-02-24                             Business Law     wykład
# ..          ...                                      ...        ...
# 304  2026-06-11                      Information Systems  ćwiczenia
# 305  2026-06-11  Operating Systems and Computer Networks  ćwiczenia
# 307  2026-06-17                     Discrete mathematics    egzamin
# 308  2026-06-26  Operating Systems and Computer Networks    egzamin
# 309  2026-09-03                     Discrete mathematics    egzamin
#
#                            Nauczyciel                  Sala Day Start time  \
# 1                 dr Katarzyna Wójcik        Paw.A 013 lab.  Pn      13:15
# 4    prof. dr hab. Andrzej Sokołowski             Paw.F 008  Wt      09:45
# 6    prof. dr hab. Andrzej Sokołowski         Paw.A 07 lab.  Wt      13:15
# 8             dr Grzegorz Kosiorowski  Rakowicka 16 sala 11  Wt      15:00
# 9                    dr Jacek Lachner  Rakowicka 16 sala 11  Wt      18:30
# ..                                ...                   ...  ..        ...
# 304           mgr inż. Justyna Olczak        Paw.A 014 lab.  Cz      16:45
# 305  prof. UEK dr hab. Joanna Wyrobek         Paw.A 07 lab.  Cz      18:30
# 307           dr Grzegorz Kosiorowski       Paw.C Nowa Aula  Śr      10:30
# 308  prof. UEK dr hab. Joanna Wyrobek         Paw.A 07 lab.  Pt      10:30
# 309           dr Grzegorz Kosiorowski             Paw.F 102  Cz      10:30
#
#     End time Duration
# 1      15:45        3
# 4      11:15        2
# 6      14:45        2
# 8      16:30        2
# 9      20:00        2
# ..       ...      ...
# 304    17:30        1
# 305    20:00        2
# 307    13:00        3
# 308    12:15        2
# 309    13:00        3
#
# [123 rows x 9 columns]
